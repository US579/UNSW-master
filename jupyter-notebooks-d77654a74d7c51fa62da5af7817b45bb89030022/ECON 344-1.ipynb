# %% [markdown]
# # ECON 344

# %% [markdown]
# #### Group Assignment
#
# Situation analysis - May 23
# Marketing objectives - June 6
# Marketing strategies - June 27
# Written component - July 11
# Presentation dates:
#
# * Set A: July 11
# * Set B: July 18
# * Set C: July 25
#
# #### Tests
#
# Test 1 - June 6
# Test 2 - July 4

# %% [markdown]
# # Lecture 1: May 2, 2018
#
# ## What marketing is and what it is not
#
# Definition from American Marketing Association:
# > Marketing is an organizational function and a set of processes for _creating_, _communicating_, and _delivering value_ to customers and for managing customer relationships in a way that benefit the organizations stackholders
#
# **Requirements for marketing to occur** (4 factors):
#
# * Two or more parties with unsatisfied needs
# * Desire and ability to satisfy these needs
# * A way for the parties to communicate
# * Something to exchange
#
# **Breadth and depth of marketing**:
# * What is a market
# * Who markets
# * What is marketed
#     * Social marketing
# * Who buys and uses what is marketed
#     * Ultimate customers
#     * Organizational buyers
# * Who benefits
#
# The diverse factors influencing marketing activities
#
# An organization's marketing department relates to many people, gropus, and forces:
# ![An organization's marketing department relates to many people, groups, and forces](Assets/marketing-1.1.png)
#
# ## How marketing discovers and satisfies consumer needs
#
# * Discovering consumer needs
#     * Consumer needs and consumer wants
#
# Marketing's _first_ task: discovering consumer needs!
# > Potential consumers: The market $\rightarrow$ Information about needs $\rightarrow$ (Organization's marketing department) Discover consumer needs
#
# Satisfying consumer needs.
#
# * _Target market_
#
# The Four Ps: Controllable _Marketing Mix_ Factors:
#
# * Product
# * Price
# * Promotion
# * Place
#
# The Uncontrollable, _Environmental Factors_.
#
# What about... high-technology or new-to-world products?
#
# Marketing's _second_ task: satisfying consumer needs:
# ![Marketing second task](Assets/marketing-1.3.png)
#
# ## The marketing program
#
# Ideas for serving consumer needs must be translated into a tangible **marketing program**,
# > a plan that integrates the marketing mix elements to provide a product, service, or idea to consumers
#
# **Six different orientations in the history of N.A. business**:
#
# * Production era: 'til 1930
# * Sales era: 1920 - 1960
# * Marketing concept era: 1950 - 1990
# * Market orientation era: since 1990
# * Customer experience management era: since 2000
# * Social media marketing era: since 2005
#
# ## How marketing become so important
#
# Ethics and social responsibility:
#
# * Balancing the interests of different groups
#
# Ethics
#
# Social responsibility:
#
# * Social marketing concept
# * Macromarketing
# * Micromarketing

# %% [markdown]
# # Lecture 2: May 9, 2018
#
# ## Developing Successful Marketing Strategies
#
# ### Kinds of Organizations
#
# Today's organization:
#
# * Kinds of organization
#     * Business firms
#     * Non-profit organizations
# * What is strategy?
# * Structure of today's organization
#     * Corporate level
#     * Strategic business unit level
#     * Functional level
#
# ![figure 2.1](Assets/marketing-2.1.png)
#
# #### Learning Review
#
# What is **strategy**?
#
# > An organization's long-term course of action designed to deliver a unique customer experience while achieving its goals.
#
# What is **marketing accountability**?
#
# > The responsibility for the systematic management of marketing resources and processes to achieve measurable gains in return on marketing investment and increased marketing efficiency, while maintaining quality and increasing the value of the corporation.
#
# What are examples of a functional level in an organization?
#
# > The marketing department or information systems department are examples of functional levels in an organization.
#
# ### Strategy in Visionary Organizations
#
# Organizational foundation: why does it exist?
#
# * Core values
# * Mission
# * Organizational culture
#
# > Today's organization uses key elements to (1) establish a foundation and (2) set a direction using (3) its strategies that enable it to develop and market its offerings successfully:
# * Organizational foundation (why)
#     * core values
#     * mission (vision)
#     * organizational culture
# * Organizational direction (what)
#     * business
#     * goals (objectives)
#         * long-term
#         * short-term
# * Organizational strategies (how)
#     * by level
#         * corporate
#         * SBU (strategic business unit)
#         * functional
#     * by offering
#         * product
#         * service
#         * idea
#         * experience
#
# Organizational direction: what will it do?
#
# * Business
# * Goals (SMART)
#     * Profit
#     * Sales
#     * Market share
#
# Organizational strategies: how will it do it?
#
# * variation by level
# * variation by offering
#
# #### Learning Review
#
# What is the meaning of an organization's mission?
#
# > It is a statement of the organization's function in society.
#
# What is the _difference_ between an organization's **business** and its **goals**?
#
# > A _business_ describes the clear, broad, underlying industry or market sector of an organization's offering.
# >
# > _Goals_ are statements of an accomplishment of a task to be achieved, often by a specific time.
#
# ### Setting Strategic Direction
#
# A look around: where are we now?
#
# * Competencies
#     * competitive advantage
#     * quality
#     * benchmarking
# * Customers
# * Competitors
#
# Growth strategies: where do we want to go?
#
# * Business Portfolio Analysis
#     * BCG Analysis
#
# **BCG matrix** is a framework created by _Boston Consulting Group_ to evaluate the strategic position of the business brand portfolio and its potential.
# It classifies business portfolio into four categories based on industry attractiveness (growth rate of that industry) and competitive position (relative market share).
#
# ![bcg analysis](Assets/marketing-2.3.png)
#
# Growth strategies: where do we want to go? (cont.)
#
# * Market-Product Analysis
#
# ![market product anlaysis](Assets/marketing-2.4.png)
#
# ---
#
# Tracking strategic performance with marketing dashboards and metrics:
#
# * Car dashboard and marketing dashboards
# * Dashboards, metrics, and plans
#
# #### Learning Review
#
# What is a **business portfolio analysis**?
#
# > Business portfolio analysis is the understanding of a firm's strategic business units (SBU's) as though they were a collection of separate investments.
#
# What is a **marketing dashboard**?
#
# > The visual computer display of the essential information related to achieving a marketing objective.
#
# ### The Strategic Marketing Process
#
# #### The planning phase
#
# * Step 1: Situation (SWOT) Analysis
# * Step 2: Market-Product Focus and Goal Setting
#     * Set marketing and product goals
#     * Select target markets
#     * Find _points of difference_
#     * Position the product
# * Step 3: Marketing Program
#     * Product, Price, Promotion & Place (distribution) strategies
#
# ![strategic marketing process](Assets/marketing-2.5.png)
#
# ![cohesive marketing program](Assets/marketing-2.6.png)
#
# #### Learning Review
#
# What is the difference between a _strength_ and an _opportunity_ in a SWOT analysis?
#
# > In a SWOT analysis, a strength is a favourable evaluation of the internal situation at the level of the entire organization, the business unit, the product line, or the specific product.
# > An opportunity is a favourable evaluation of the external situation at the level of the entire organization, the business unit, the product line, or the specific product.
#
# What is **market segmentation**?
#
# > Market segmentation is the process of aggregating prospective buyers into groups, or segments, that (1) have common needs and (2) will respond similarly to a marketing action.
#
# What are **points of difference** and why are they important?
#
# > Points of difference are those characteristics of a product that make it superior to competitive substitutes.
# > This concept is the single most important factor in the success or failure of a new product.
#
# #### The implementation phase
#
# * Obtaining resources
# * Designing the marketing organization
# * Developing schedules
# * Execute the marketing program
#     * marketing strategy
#     * marketing tactics
#
# #### The evaluation phase
#
# * Comparing results with plans to identify deviations
# * Acting on deviations
#     * Correcting a negative deviation
#     * Exploiting a positive deviation
#
# #### Learning Review cont.
#
# What is the implementation phase of the strategic marketing process?
#
# > The four components of the implementation phase include:
# >
# > 1. obtaining resource,
# > 2. designing the marketing organization,
# > 3. developing schedules, and
# > 4. actually executing the marketing program designed in the planning phase
#
# How do the goals set for a marketing program in the planning phase relate to the evaluation phase of the strategic marketing process?
#
# > The evaluation phase of the strategic marketing process seeks to keep the marketing program moving in the direction set for it.
# >
# > Accomplishing this requires the marketing manager (1) to compare the results of the marketing program with the goals in the written plans to identify deviations, and (2) to act on these deviations-correcting negative deviations and exploiting positive ones.

# %% [markdown]
# # Lecture 3: May 16, 2018
#
# ## Scanning the Marketing Environment
#
# ### The Importance of Environment Scanning
#
# Tracking Environmental Trends
#
# ![environmental trends](Assets/marketing-3.1.png)
#
# An Environmental Scan of Canada
#
# ![environmental scans](Assets/marketing-3.2.png)
#
# ### Social Forces
#
# Demographics
#
# * The world population at a glance
#     * Top 10 most populous countries by 2050, accumulating to 55.8% of world population
#         * India
#         * China
#         * USA
#         * Nigeria
#         * Indonesia
#         * Pakistan
#         * Brazil
#         * Bangladesh
#         * Philippines
#         * Democratic Republic of Congo
# * The Canadian population
# * Generational Cohorts
#     * Baby boomers
#     * Generation X
#     * Generation Y
#
# ---
#
# * The Canadian family
#     * Blended family
# * Population shifts
#     * Census metropolitan areas (CMA's)
# * Ethnic diversity
#     * Ethnic marketing
# * Culture
#     * Changing attributes and values
#         * Value consciousness
#
# #### Learning Review
#
# Describe three generational cohort.
#
# > Baby Boombers - 1946 to 1964
# >
# > Generation X - 1965 to 1976
# >
# > Generation Y - 1977 to 1994
#
# Why are many companies developing multicultural marketing programs?
#
# > They recognize the growing ethnic diversity within Canada.
#
# What is a census metropolitan area?
#
# > Census metropolitan areas (CMAs) are geographic labour market areas having a population of 100k or more.
#
# ### Economic Forces
#
# * The Economy
# * Macroeconomic conditions
# * Consumer income
#     * Gross income
#     * Disposable income
#     * Discretionary income
#
# ### Technological Forces
#
# * Technology
# * Technology's impact on marketers
#     * Electronic commerce
#     * Intranet
#     * Extranets
#     * Marketspace
#     * E-business
#     * E-marketing
#     * E-commerce
#     * Social media
# * Technology's impact on customers
#     * Blogs
#     * Consumer-generated content (CGC)
#     * Consumer-to-consumer (C2C)
#     * Customer-to-business (C2B)
#
# ### Competitive Forces
#
# * Alternate forms of competition
#     * Pure competition
#     * Monopoly
#     * Oligopoly
#     * Monopolistic competition
# * Components of competition
#     * Entry
#         * Barrier of entry
#     * Power of buyers and suppliers
#     * Existing competitors and substitutes
# * Small business as competitors
# * Pure-play online competitors
#
# #### Learning Review
#
# What is the difference between a consumer's disposable and discretionary income?
#
# > While the disposable income is what is left after paying taxes and for such necessities as food, shelter, clothing and transportation; discretionary income is what remains after all taxes and necessities have been covered.
#
# How does technology impact customer value?
#
# > Technology impacts customer value partly to reduce costs associated with its use.
# >
# > It also provides value for the development of new, better products.
# >
# > Existing products and the ways in which they are produced may also be changed.
#
# In pure competition, there are a very large number of sellers.
#
# ### Regulatory Forces
#
# * Protecting Competition and Consumers
#     * The Competition Act
#         * The most important legislation designed to protect competition and consumers in Canada
#     * Competition Tribunal Act
#     * Self-regulation
#         * An alternate to legislation protecting competition and consumers
#     * Consumerism
#         * A movement to increase the influence, power, and rights of consumers in dealing with institutions
#
# ![acts](Assets/marketing-3.4.png)

# %% [markdown]
# # Lecture 4: May 23, 2018
#
# ## Consumer Behaviour
#
# Enlightened car-makers know what customers value: consumer behaviour.
#
# ### Consumer Purchase Decision Process
#
# 1. Problem recognition
#     * perceiving a need
# 2. Information search
#     * seeking value
# 3. Alternative evaluation
#     * assessing value
#         * evaluation criteria
#         * consideration set
# 4. Purchase decision
#     * buying value
# 5. Post-purchase behaviour
#     * value in consumption or use
#     * cognitive behaviour
#
# ![comparison of problem-solving variations](Assets/marketing-5.2.png)
#
# ![influence on the consumer purchase decision process](Assets/marketing-5.3.png)
#
# #### Learning Review
#
# What is the term for post-purchase anxiety?
#
# > Cognitive dissonance
#
# ### Psychological Influences on Consumer Behaviour
#
# Motivation and personality
#
# * Motivation
# * Personality
#     * National character
#     * Self-concept
#
# Perception
#
# * Selective perception
#     * subliminal perception
# * Perceived risk
#
# Hierarchy of needs (think pyramid):
#
# 1. Self-actualization needs
#     * self-fulfillment
# 2. Personal needs
#     * status, respect, prestige
# 3. Social needs
#     * Friendship, belonging, love
# 4. Safety needs
#     * Freedom from harm, financial security
# 5. Physiological needs
#     * Food, water, shelter, oxygen
#
# Learning
#
# * Behavioural learning
# * Cognitive learning
# * Brand loyalty
#
# Values, beliefs, attitudes
#
# Attitude change
#
# Lifestyle
#
# #### Learning Review
#
# What three attitude-change approaches are most common?
#
# > Marketers use three approaches to try to change consumer attitude toward products and brands:
# >
# > 1. Changing beliefs about the extent to which a brand has certain attributes
# > 2. Changing the perceived importance of attributes
# > 3. Adding new attributes to the product
#
# What does lifestyle mean?
#
# > A mode of living that is identified by how people spend their time and resources, what they consider important in their environment, and what they think of themselves and the world around them.
#
# ### Sociocultural Influences on Consumer Bahaviour
#
# Personal influence
#
# * Opinion leadership
# * Word of mouth
#     * Buzz marketing
#     * Viral marketing
#
# Reference groups
#
# Family influence
#
# * Consumer socialization
# * Family life cycle
# * Family decision making
#
# ![modern family life cycle](Asset/marketing-5.6.png)
#
# Social class
#
# Culture and subculture
#
# * French Canadian subculture
# * Acadian subculture
# * Chinese Canadian subculture
# * Other ethnic subcultures
#
# #### Learning Review
#
# What are the two primary forms of personal influence?
#
# > Opinion leaders and word of mouth
#
# Which types of reference groups are marketers concerned with?
#
# > Marketers are most concerned with three types of reference groups:
# >
# > 1. membership group,
# > 2. aspiration group, and
# > 3. dissociative group.
#
# What is an ethnic subculture?
#
# > An ethnic subculture is a segment of larger society whose members are thought, by themselves and/or others, to have a common origin and to participate in shared activities believed to be culturally significant.

# %% [markdown]
# # Lecture 5: May 30, 2018
#
# ## Marketing Research: From Information to Action
#
# ### Advantages of Social Media
#
# Social media offers the following strategic advantages over traditional marketing research:
#
# * offers the infinite panel
# * offers the infinite survey
# * provides real-time results
# * can reveal elusive "hidden" insights
# * captures the consumers in their words
#
# ### What is Marketing Research?
#
# The process of defining a marketing problem and opportunity, systematically collecting and analyzing information, and recommending actions to improve an organization's marketing activities.
#
# ### Types of Marketing Research
#
# * Exploratory research
#     * done with the expectation that more conclusive research will be concluded later
#     * its initial purpose is to provide the researcher with a better understanding of the problem dimensions
# * Descriptive research
#     * provides the researcher with a general understanding of the marketing problem and seeks _conclusive_ data to answer questions necessary to determine a particular course of action
# * Casual research
#     * preceded by exploratory and descriptive research
#     * identify cause-and-effect relationship among variables
#
# ### The Marketing Research Process
#
# Scientific Method:
#
# * Reliability
#     * the ability to replicate research results under identical environmental conditions
# * Validity
#     * involves the notion of whether the research measured what was originally intended
#
# ![basic marketing research process](Assets/marketing-8.1.png)
#
# The four basic stages in the marketing research process:
#
# 1. Problem cognition
# 2. Formal research design
# 3. Data collection and analysis
# 4. Conclusions and report
#
# #### Problem Definition
#
# Define the scope and nature of the marketing problem.
#
# > "A problem well defined is a problem half-solved."
#
# Exploratory research
#
# * Secondary data
#     * also called historical data, are data previously collected and assembled for some project other than the one at hand
# * Primary data
# * Focus group
#     * informal interview sessions in which 6 to 10 persons relevant to the research project are brought together in a room with a moderator to discuss topics surrounding the marketing research problem
# * Depth interviews
#
# #### Formal Research Design
#
# * Survey
#     * a research technique used to generate data by asking people questions and recording their responses on a questionnaire
# * Experiment
#     * offers the potential for establishing cause-and-effect relationships (casual research)
# * Observation
#     * Ethnographic research
#
# ![comparing various survey types](Assets/marketing-8.3.png)
#
# Typical problems in wording questions:
#
# * leading questions
# * ambiguous questions
# * unanswerable question
# * two questions in one
# * Nonexhaustive question
# * Non-mutually exclusive answers
#
# Sampling: process of gathering data from a subset of the total population rather than from all members (census) of that particular population.
# Types of sampling:
#
# * Probability sampling
# * Non-probability sampling
#
# #### Data Collection and Analysis
#
# Once the research design has been formalized, the process of gathering or collecting data begins.
#
# #### Conclusions and Report
#
# Interpret the information and make conclusions with regard to managerial decision making.
#
# The report to highlight the important results and conclusions.
#
# #### Ethical Issues in the Marketing Research Process
#
# Professional marketing researchers must make ethical decisions regarding the collecting, using, and reporting of research data.
#
# #### Using I.T. to Trigger Marketing Actions
#
# The Marketing Manager's View of Sales Drivers
#
# * Marketing information system
#
# Key elements of a marketing information system:
#
# * Data warehouse
# * Sensitivity analysis
#
# ![i.t. marketing actions](Assets/marketing-8.7.png)
#
# Data mining: searching the data ocean
#
# #### Learning Review
#
# What does a marketing manager mean when she talks about a sales "driver"?
#
# > Many sales factors or "drivers" may influence the buying decisions of a household or organization and ultimately, its sale.
# > These drivers include both the controllable marketing mix factors, like product and distribution, and uncontrollable factors like competition and the changing tastes of households or organization buyers.
#
# What does data mining differ from traditional marketing research?
#
# > Traditional marketing research typically involves developing a hypothesis about a driver and then collect data.
# > In contrast, data mining is the extraction of hidden predictive information from large databases.

# %% [markdown]
# ## Marketing Segmentation, Targeting, and Positioning
#
# Marketing segmentation - linking market need to an organization's marketing program:
#
# 1. Identify market needs
#     * Benefit in terms of:
#         * Product features
#         * Expense
#         * Quality
#         * Savings in time and convenience
# 2. Link needs to actions
#     * Take steps to segment and target markets
# 3. Execute marketing program actions
#     * A marketing mix in terms of:
#         * Product
#         * Price
#         * Promotion
#         * Place (distribution)
#
# ### Why Segment Markets?
#
# When to segment markets
#
# * One product and multiple market segments
# * Multiple products and multiple market segments
# * Segments of One: Mass Customization
#
# #### Learning Review
#
# Market segmentation involves aggregating prospective buyers into groups that have two key characteristics.
# What are they?
#
# > 1. have common needs and
# > 2. will respond similarly to a marketing action
#
# When should a firm segment its markets?
#
# > When the firm's expectation is that it will increase its sales, profit, and return on investment, it is normally worthwhile to segment markets.
#
# ### Steps in Segmenting and Targeting Markets
#
# 1. Group potential buyers into segments
#     * Criteria to use in forming segments:
#         * Potential for increased profit
#         * Similarity of needs of potential buyers within a segment
#         * Difference of needs of buyers among segments
#         * Potential of marketing action to reach a segment
#         * Simplicity and cost of assigning potential buyers to segments
#     * Ways to segment consumer markets
#         * Geographic segmentation (e.g., region, density, climate)
#         * Demographic segmentation (e.g., age, martial status, education)
#         * Psychographic segmentation (e.g., lifestyle)
#         * Behavioural segmentation
#             * Usage rate
#             * 80/20 rule
# 2. Group products to be sold into categories
# 3. Develop a _Market-Product Grid_ and estimate size of markets
# 4. Select target markets
#     * Criteria to use in picking the target segments:
#         * Market size
#         * Expected growth
#         * Competitive position
#         * Cost of reaching the segment
#         * Compatibility with objectives and resources
#     * Choose the segments
# 5. Take marketing actions to reach target markets
#
# #### Learning Review
#
# In a market-product grid, what factor is estimated or measured for each of the cells?
#
# > The size of the market in each cell, along with the market-product combination, must be estimated.
#
# ### Positioning the Product
#
# * Product positioning
# * Product repositioning
#
# Two approaches to _Prodct Repositioning_:
#
# * Head-to-head positioning
# * Differentiation
#
# Writing a _Positioning Statement_
#
# Product Positioning using _Perceptual Maps_
#
# ### Sales Forecasting Techniques
#
# **Market potential** or **Industry potential**
#
# **Sales forecast** or **Company forecast**
#
# Judgements of the Decision Maker
#
# * Direct forecast
# * Lost-horse forecast
#
# Surveys of Knowledgeable Groups
#
# * Surveys of buyers' intentions forecast
# * Salesforce survey forecast
#
# Statistical Methods
#
# * Trend extrapolation
# * Linear trend extrapolation
#
# #### Learning Review
#
# Why do marketers use perceptual maps in product positioning decisions?
#
# > Perceptual maps are used by marketers in product positioning decisions because it enables them to see how consumers perceive competing products or brands and then take marketing actions.
#
# What are the three kinds of sales forecasting techniques?
#
# > 1. Judgements of the decision maker
# > 2. Surveys of knowledgeable groups
# > 3. Statistical methods
